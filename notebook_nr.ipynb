# %%
import pandas as pd

# %% [markdown]
# # nr

# %%
from processing import National, Base

# %%
nr = National()

# %% [markdown]
# ## 2002

# %%
df_02 = pd.read_excel('data/nrsr/nrsr2002.xls')

# %%
df_02.head()
# Out:
#      Unnamed: 0                Unnamed: 1                   Unnamed: 2  \
# 0           NaN                     Počet  Platné hlasy (počet/podiel)
# 1       \nOkres  platných\nhlasov\n spolu                          SZS
# 2                                     NaN                          NaN
# 3  Bratislava I                     30501                          258
# 4           NaN                       NaN                         0.84
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       SDKÚ       SDPO        SDĽ       SMER       HZDS        OKS
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3      12400         23        296       2707       3539        356
# 4      40.65       0.07       0.97       8.87       11.6       1.16
#
#   Unnamed: 9  ... Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        HZD  ...         ANO       B-RRS         ŽAR         SDA         SNJ
# 2        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 3        852  ...        1639          10          71         946          39
# 4       2.79  ...        5.37        0.03        0.23         3.1        0.12
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0         NaN         NaN         NaN         NaN         NaN
# 1        NOSP         SNS        ROSA       ROISR       P SNS
# 2         NaN         NaN         NaN         NaN         NaN
# 3          93         929          19           1         325
# 4         0.3        3.04        0.06           0        1.06
#
# [5 rows x 27 columns]

# %%
df_02 = nr.preprocess_2002(df_02)

# %%
df_02.head()
# Out:
#             Okres  SZS   SDKÚ SDPO  SDĽ  SMER  HZDS  OKS   HZD ROMA  ...  \
# 0    Bratislava I  258  12400   23  296  2707  3539  356   852    6  ...
# 1   Bratislava II  586  22222   82  639  7737  8992  415  1997   19  ...
# 2  Bratislava III  388  13209   42  394  4889  5913  312  1256    7  ...
# 3   Bratislava IV  505  20036   71  522  7196  6278  446  1611   13  ...
# 4    Bratislava V  808  25795   84  746  9921  7467  554  1972   30  ...
#
#   B-RRS  ŽAR   SDA SNJ NOSP   SNS ROSA ROISR P SNS Kód Okresu
# 0    10   71   946  39   93   929   19     1   325        101
# 1    29  252  1832  61  207  2404   67    24  1053        102
# 2    12  141  1092  64  153  1569   60     5   800        103
# 3    18  270  1739  74  208  1775   75    11   872        104
# 4    29  396  2378  79  220  2413   80    21  1541        105
#
# [5 rows x 27 columns]

# %%
df_02.shape
# Out:
# (80, 27)

# %%
nr.process_a(df_02, 2002)

# %%
df_test = nr.df

# %%
df_test.head()
# Out:
#    election_year election_type district_id   district_name  \
# 0           2002         NR SR         101    Bratislava I
# 1           2002         NR SR         102   Bratislava II
# 2           2002         NR SR         103  Bratislava III
# 3           2002         NR SR         104   Bratislava IV
# 4           2002         NR SR         105    Bratislava V
#
#   original_party_name party_name  votes
# 0                 SZS        SZS    258
# 1                 SZS        SZS    586
# 2                 SZS        SZS    388
# 3                 SZS        SZS    505
# 4                 SZS        SZS    808

# %% [markdown]
# ## 2006

# %%
df_06 = pd.read_excel('data/nrsr/nrsr2006.xls')

# %%
df_06.head()
# Out:
#                                          Počet a podiel platných hlasov odovzdaných pre  politické strany podľa okresov, krajov a SR  \
# 0                                                NaN
# 1                           \nOkres, kraj,\nSR spolu
# 2                                                NaN
# 3                                       Bratislava I
# 4                                                NaN
#
#                        Unnamed: 1                     Unnamed: 2 Unnamed: 3  \
# 0  Počet\nplatných\nhlasov\nspolu  Platné hlasy (počet / podiel)        NaN
# 1                             NaN                             ĽB     S.O.S.
# 2                             NaN                            NaN        NaN
# 3                          23 927                             20          6
# 4                             NaN                           0,08       0,02
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1   Misia 21        SDĽ        ZRS        KDH      SLNKO        ANO  ...
# 2        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 3         33         28          9      2 621         34        224  ...
# 4       0,13       0,11       0,03      10,95       0,14       0,93  ...
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         OKS          PS   ĽS - HZDS         ASV         KSS         SĽS
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         295          52       1 511          13         545          48
# 4        1,23        0,21        6,31        0,05        2,27        0,20
#
#   Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22
# 0         NaN         NaN         NaN         NaN
# 1   SDKÚ - DS        SMER         SNS       NÁDEJ
# 2         NaN         NaN         NaN         NaN
# 3      10 676       3 522       1 417          71
# 4       44,61       14,71        5,92        0,29
#
# [5 rows x 23 columns]

# %%
df_06 = National.preprocess_2006(df_06)

# %%
df_06.head()
# Out:
#             Okres  ĽB S.O.S. Misia 21  SDĽ ZRS    KDH SLNKO  ANO  HZD  ...  \
# 0    Bratislava I  20      6       33   28   9  2 621    34  224  122  ...
# 1   Bratislava II  62     27       50   92  55  3 945   109  659  209  ...
# 2  Bratislava III  37     14       39   49  23  2 565    48  408  125  ...
# 3   Bratislava IV  73     15       70   52  48  3 826    82  812  155  ...
# 4    Bratislava V  75     17       42  100  63  4 138   108  932  240  ...
#
#     PS ĽS - HZDS ASV    KSS  SĽS SDKÚ - DS    SMER    SNS NÁDEJ Kód Okresu
# 0   52     1 511  13    545   48    10 676   3 522  1 417    71        101
# 1  123     3 784  60  1 540   99    19 958  10 860  4 168   228        102
# 2   61     2 474  24  1 094   63    11 900   6 785  2 817   162        103
# 3  116     2 705  55  1 259  110    18 218   9 397  3 583   225        104
# 4  208     3 006  52  1 586  153    22 012  12 925  4 907   253        105
#
# [5 rows x 23 columns]

# %%
df_06.shape
# Out:
# (80, 23)

# %%
df_06.shape
# Out:
# (80, 23)

# %%
nr.process_a(df_06, 2006)

# %%
nr.df.shape
# Out:
# (3680, 7)

# %% [markdown]
# ## 2010

# %%
df_10 = pd.read_excel('data/nrsr/nrsr2010.xls')

# %%
df_10.head()
# Out:
#    Kód\nokresu   Názov\nokresu  Počet\nvoleb.\nokrskov  \
# 0          101    Bratislava I                      34
# 1          102   Bratislava II                     107
# 2          103  Bratislava III                      64
# 3          104   Bratislava IV                      82
# 4          105    Bratislava V                     107
#
#    Počet\nvoličov\nzapísaných\nv zoznamoch\nvoličov  \
# 0                                             38113
# 1                                             97490
# 2                                             54886
# 3                                             84085
# 4                                            105818
#
#    Počet\nvoličov,\nktorí sa\nzúčastnili\nna hlasovaní  \
# 0                                              25372
# 1                                              62356
# 2                                              36477
# 3                                              54136
# 4                                              64554
#
#    Počet\nvoličov,\nktorí\nzaslali\nnávratnú\nobálku\nz cudziny  \
# 0                                                168
# 1                                                213
# 2                                                137
# 3                                                270
# 4                                                287
#
#    Počet\nvoličov,\nktorí\nhlasovali\nosobne  Počet\nplatných\nhlasov\nspolu  \
# 0                                      25188                           25045
# 1                                      62094                           61750
# 2                                      36323                           36097
# 3                                      53806                           53615
# 4                                      64229                           64110
#
#    EDS  Únia  ...  KSS   SNS   ND  ZRS   KDH  ĽSNS  SDKÚ - DS  AZEN   SMER  \
# 0   42   173  ...   80   700   65    9  2739    95       8161    24   4738
# 1  104   682  ...  237  2208  163   24  4666   345      17742    54  15136
# 2   61   303  ...  173  1454  109   29  3090   209      10349    45   9310
# 3   92   617  ...  185  1765  144   41  4699   313      15738    79  12888
# 4  111   700  ...  262  2325  186   43  4530   474      18882    82  15232
#
#    MOST - HÍD
# 0        2772
# 1        5954
# 2        2508
# 3        3924
# 4        5133
#
# [5 rows x 26 columns]

# %%
df_10 = National.preprocess_2010(df_10)

# %%
df_10.head()
# Out:
#    Kód Okresu           Okres  EDS  Únia  SRK  Paliho Kapurková    SaS   SDĽ  \
# 0         101    Bratislava I   42   173   14               118   4159   323
# 1         102   Bratislava II  104   682   18               373  10592  1077
# 2         103  Bratislava III   61   303   10               279   6189   719
# 3         104   Bratislava IV   92   617    4               363  10257  1014
# 4         105    Bratislava V  111   700   24               552  12219  1433
#
#    SMK - MKP  ĽS - HZDS  KSS   SNS   ND  ZRS   KDH  ĽSNS  SDKÚ - DS  AZEN  \
# 0      202.0        631   80   700   65    9  2739    95       8161    24
# 1      622.0       1753  237  2208  163   24  4666   345      17742    54
# 2      174.0       1086  173  1454  109   29  3090   209      10349    45
# 3      183.0       1309  185  1765  144   41  4699   313      15738    79
# 4      425.0       1497  262  2325  186   43  4530   474      18882    82
#
#     SMER  MOST - HÍD
# 0   4738        2772
# 1  15136        5954
# 2   9310        2508
# 3  12888        3924
# 4  15232        5133

# %%
nr.process_a(df_10, 2010)

# %%
nr.df.shape
# Out:
# (5102, 7)

# %% [markdown]
# ## 2012

# %%
df_12 = pd.read_excel('data/nrsr/nrsr2012.xls')

# %%
df_12.head()
# Out:
#    Kód\nokresu   Názov\nokresu  Počet\nvoleb.\nokrskov  \
# 0          101    Bratislava I                      34
# 1          102   Bratislava II                     107
# 2          103  Bratislava III                      66
# 3          104   Bratislava IV                      82
# 4          105    Bratislava V                     107
#
#    Počet\nvoličov\nzapísaných\nv zoznamoch\nvoličov  \
# 0                                             38218
# 1                                            100712
# 2                                             56713
# 3                                             85025
# 4                                            105930
#
#    Počet\nvoličov,\nktorí sa\nzúčastnili\nna hlasovaní  \
# 0                                              24851
# 1                                              62586
# 2                                              36331
# 3                                              54439
# 4                                              64075
#
#    Počet\nvoličov,\nktorí\nzaslali\nnávratnú\nobálku\nz cudziny  \
# 0                                                184
# 1                                                243
# 2                                                191
# 3                                                260
# 4                                                920
#
#    Počet\nvoličov,\nktorí\nhlasovali\nosobne  Počet\nplatných\nhlasov\nspolu  \
# 0                                      24628                           24479
# 1                                      62181                           61560
# 2                                      36122                           35752
# 3                                      54017                           53410
# 4                                      63104                           63090
#
#    Zelení   KDH  ...  99%  ĽS-HZDS  +1 HLAS   SF  Obyčajní ľudia  SDKÚ - DS  \
# 0      53  3013  ...  267      111        6   71              28       4495
# 1     167  5583  ...  794      305       47  337              89       8557
# 2      97  3512  ...  433      189       16  136              52       5029
# 3     148  5203  ...  674      218       32  264              73       7378
# 4     203  5342  ...  962      237       60  400             117       8061
#
#    SOSKA  SMK-MKP  SSS - NM  SŽS
# 0     32      179       157   28
# 1    121      601       504   75
# 2     60      165       246   26
# 3    110      187       392   55
# 4    133      425       676   65
#
# [5 rows x 34 columns]

# %%
df_12 = National.preprocess_2010(df_12)

# %%
df_12.head()
# Out:
#    Kód Okresu           Okres  Zelení   KDH  SDĽ   SNS  OĽaNO   SaS  PaS  \
# 0         101    Bratislava I      53  3013   36   653   2198  3951   75
# 1         102   Bratislava II     167  5583   69  2059   5182  8689  237
# 2         103  Bratislava III      97  3512   39  1422   3409  4951  158
# 3         104   Bratislava IV     148  5203   64  1866   5151  8097  226
# 4         105    Bratislava V     203  5342   73  2244   6090  9010  368
#
#    NÁŠ KRAJ  ...  99%  ĽS-HZDS  +1 HLAS   SF  Obyčajní ľudia  SDKÚ - DS  \
# 0        18  ...  267      111        6   71              28       4495
# 1        43  ...  794      305       47  337              89       8557
# 2        22  ...  433      189       16  136              52       5029
# 3        27  ...  674      218       32  264              73       7378
# 4        46  ...  962      237       60  400             117       8061
#
#    SOSKA  SMK-MKP  SSS - NM  SŽS
# 0     32      179       157   28
# 1    121      601       504   75
# 2     60      165       246   26
# 3    110      187       392   55
# 4    133      425       676   65
#
# [5 rows x 28 columns]

# %%
df_12.shape
# Out:
# (79, 28)

# %%
nr.process_a(df_12, 2012)

# %% [markdown]
# ## 2016

# %%
df_16 = pd.read_excel('data/nrsr/nrsr2016.xlsx')

# %%
df_16.head()
# Out:
#   Výsledky hlasovania pre politické subjekty podľa okresov    Unnamed: 1  \
# 0                                                NaN                 NaN
# 1                                         Kód okresu               Okres
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                101        Bratislava I
#
#                     Unnamed: 2             Unnamed: 3  \
# 0                          NaN                    NaN
# 1  Počet platných hlasov spolu                    TIP
# 2                          NaN  Počet platných hlasov
# 3                          NaN                    NaN
# 4                        26227                     45
#
#                    Unnamed: 4  \
# 0                         NaN
# 1                         NaN
# 2  Podiel platných hlasov v %
# 3                         NaN
# 4                        0.17
#
#                                           Unnamed: 5  \
# 0                                                NaN
# 1                                                NaN
# 2  Počet voličov, ktorí využili právo prednostnéh...
# 3                                                NaN
# 4                                                 35
#
#                                           Unnamed: 6  \
# 0                                                NaN
# 1                                                NaN
# 2  Podiel voličov, ktorí využili právo prednostné...
# 3                                                NaN
# 4                                              77.77
#
#                          Unnamed: 7                  Unnamed: 8  \
# 0                               NaN                         NaN
# 1  STRANA MODERNÉHO SLOVENSKA (SMS)                         NaN
# 2             Počet platných hlasov  Podiel platných hlasov v %
# 3                               NaN                         NaN
# 4                                16                        0.06
#
#                                           Unnamed: 9  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2  Počet voličov, ktorí využili právo prednostnéh...  ...
# 3                                                NaN  ...
# 4                                                 12  ...
#
#                                          Unnamed: 85  \
# 0                                                NaN
# 1                                                NaN
# 2  Počet voličov, ktorí využili právo prednostnéh...
# 3                                                NaN
# 4                                                125
#
#                                          Unnamed: 86            Unnamed: 87  \
# 0                                                NaN                    NaN
# 1                                                NaN                     PD
# 2  Podiel voličov, ktorí využili právo prednostné...  Počet platných hlasov
# 3                                                NaN                    NaN
# 4                                              76.68                     38
#
#                   Unnamed: 88  \
# 0                         NaN
# 1                         NaN
# 2  Podiel platných hlasov v %
# 3                         NaN
# 4                        0.14
#
#                                          Unnamed: 89  \
# 0                                                NaN
# 1                                                NaN
# 2  Počet voličov, ktorí využili právo prednostnéh...
# 3                                                NaN
# 4                                                 31
#
#                                          Unnamed: 90            Unnamed: 91  \
# 0                                                NaN                    NaN
# 1                                                NaN                    SaS
# 2  Podiel voličov, ktorí využili právo prednostné...  Počet platných hlasov
# 3                                                NaN                    NaN
# 4                                              81.57                   7764
#
#                   Unnamed: 92  \
# 0                         NaN
# 1                         NaN
# 2  Podiel platných hlasov v %
# 3                         NaN
# 4                        29.6
#
#                                          Unnamed: 93  \
# 0                                                NaN
# 1                                                NaN
# 2  Počet voličov, ktorí využili právo prednostnéh...
# 3                                                NaN
# 4                                               6549
#
#                                          Unnamed: 94
# 0                                                NaN
# 1                                                NaN
# 2  Podiel voličov, ktorí využili právo prednostné...
# 3                                                NaN
# 4                                              84.35
#
# [5 rows x 95 columns]

# %%
df_16 = National.preprocess_2016(df_16)

# %%
df_16.head()
# Out:
# 1 Kód Okresu           Okres  TIP STRANA MODERNÉHO SLOVENSKA (SMS)  \
# 4        101    Bratislava I   45                               16
# 5        102   Bratislava II  197                               38
# 6        103  Bratislava III   96                               17
# 7        104   Bratislava IV  137                               29
# 8        105    Bratislava V  171                               47
#
# 1 OBYČAJNÍ ĽUDIA a nezávislé osobnosti (OĽANO - NOVA) DS - Ľudo Kaník ŠANCA  \
# 4                                               4050               15    60
# 5                                               8890               33   126
# 6                                               5565               23    78
# 7                                               8721               23   108
# 8                                               9388               23   136
#
# 1 SME RODINA - Boris Kollár  SZS KOALÍCIA SPOLOČNE ZA SLOVENSKO  ...  KSS  \
# 4                      1006  152                             11  ...   54
# 5                      4770  413                             56  ...  217
# 6                      2286  306                             24  ...  142
# 7                      3890  447                             34  ...  216
# 8                      5432  536                             64  ...  234
#
# 1 SDKÚ-DS SMER-SD   KDH SKOK! ĽS Naše Slovensko #SIEŤ SMK-MKP   PD    SaS
# 4     133    3929  1385   357               707  1895     163   38   7764
# 5     270   12421  2712   905              2685  4366     686  106  17800
# 6     156    7608  1614   523              1448  2709     159   50  10485
# 7     350   10672  2340   807              2605  3985     184   83  15474
# 8     231   12307  2355   936              3211  4458     344  225  17244
#
# [5 rows x 25 columns]

# %%
df_16.shape
# Out:
# (80, 25)

# %%
nr.process_a(df_16, 2016)

# %%
nr.df.shape
# Out:
# (8996, 7)

# %% [markdown]
# ## 2020

# %%
df_20 = pd.read_excel('data/nrsr/nrsr2020.xlsx')

# %%
df_20.head()
# Out:
#   Počet a podiel platných hlasov odovzdaných pre politické subjekty za okresy  \
# 0                                                NaN
# 1                                          Kód kraja
# 2                                                NaN
# 3                                                  1
# 4                                                  1
#
#           Unnamed: 1           Unnamed: 2             Unnamed: 3  Unnamed: 4  \
# 0                NaN                  NaN                    NaN         NaN
# 1        Názov kraja  Kód územného obvodu  Názov územného obvodu  Kód okresu
# 2                NaN                  NaN                    NaN         NaN
# 3  Bratislavský kraj                  101             Bratislava         101
# 4  Bratislavský kraj                  101             Bratislava         101
#
#      Unnamed: 5                  Unnamed: 6  \
# 0           NaN                         NaN
# 1  Názov okresu  Číslo politického subjektu
# 2           NaN                         NaN
# 3  Bratislava I                           1
# 4  Bratislava I                           2
#
#                                Unnamed: 7             Unnamed: 8  \
# 0                                     NaN                    NaN
# 1              Názov politického subjektu  Počet platných hlasov
# 2                                     NaN                    NaN
# 3  Slovenská ľudová strana Andreja Hlinku                     18
# 4                             DOBRÁ VOĽBA                    638
#
#                    Unnamed: 9  \
# 0                         NaN
# 1  Podiel platných hlasov v %
# 2                         NaN
# 3                        0.05
# 4                         2.1
#
#                                          Unnamed: 10  \
# 0                                                NaN
# 1  Počet voličov, ktorí využili právo prednostnéh...
# 2                                                NaN
# 3                                                 14
# 4                                                523
#
#                                          Unnamed: 11
# 0                                                NaN
# 1  Podiel voličov, ktorí využili právo prednostné...
# 2                                                NaN
# 3                                              77.77
# 4                                              81.97

# %%
df_20 = National.preprocess_2020(df_20)

# %%
df_20.head()
# Out:
# 1 Kód Okresu         Okres                              party_name votes
# 3        101  Bratislava I  Slovenská ľudová strana Andreja Hlinku    18
# 4        101  Bratislava I                             DOBRÁ VOĽBA   638
# 5        101  Bratislava I                    Sloboda a Solidarita  4566
# 6        101  Bratislava I                              SME RODINA  1042
# 7        101  Bratislava I                 Slovenské Hnutie Obrody     9

# %%
nr.process_b(df_20, 2020)

# %%
nr.df.shape
# Out:
# (10911, 7)

# %% [markdown]
# ## 2023

# %%
df_23 = pd.read_excel('data/nrsr/nrsr2023.xlsx')

# %%
df_23.head()
# Out:
#   Počet a podiel platných hlasov odovzdaných pre politické subjekty za okresy  \
# 0                                                NaN
# 1                                          Kód kraja
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#           Unnamed: 1           Unnamed: 2             Unnamed: 3  Unnamed: 4  \
# 0                NaN                  NaN                    NaN         NaN
# 1        Názov kraja  Kód územného obvodu  Názov územného obvodu  Kód okresu
# 2  Bratislavský kraj                  101             Bratislava         101
# 3  Bratislavský kraj                  101             Bratislava         101
# 4  Bratislavský kraj                  101             Bratislava         101
#
#      Unnamed: 5                  Unnamed: 6                   Unnamed: 7  \
# 0           NaN                         NaN                          NaN
# 1  Názov okresu  Číslo politického subjektu   Názov politického subjektu
# 2  Bratislava I                           1  Pirátska strana - Slovensko
# 3  Bratislava I                           2                      PRINCÍP
# 4  Bratislava I                           3        Progresívne Slovensko
#
#               Unnamed: 8                  Unnamed: 9  \
# 0                    NaN                         NaN
# 1  Počet platných hlasov  Podiel platných hlasov v %
# 2                     49                        0.17
# 3                     11                        0.03
# 4                  11804                       41.59
#
#                                          Unnamed: 10  \
# 0                                                NaN
# 1  Počet voličov, ktorí využili právo prednostnéh...
# 2                                                 30
# 3                                                  8
# 4                                               9545
#
#                                          Unnamed: 11
# 0                                                NaN
# 1  Podiel voličov, ktorí využili právo prednostné...
# 2                                              61.22
# 3                                              72.72
# 4                                              80.86

# %%
df_23 = National.preprocess_2020(df_23)

# %%
df_23.head()
# Out:
# 1 Kód Okresu         Okres                                         party_name  \
# 2        101  Bratislava I                        Pirátska strana - Slovensko
# 3        101  Bratislava I                                            PRINCÍP
# 4        101  Bratislava I                              Progresívne Slovensko
# 5        101  Bratislava I                         SPOLOČNE OBČANIA SLOVENSKA
# 6        101  Bratislava I  OĽANO A PRIATELIA: OBYČAJNÍ ĽUDIA (OĽANO), NEZ...
#
# 1  votes
# 2     49
# 3     11
# 4  11804
# 5      6
# 6   1172

# %%
nr.process_b(df_23, 2023)

# %%
nr.df.shape
# Out:
# (12909, 7)
