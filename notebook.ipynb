# %%
import pandas as pd

# %% [markdown]
# # nr

# %%
from processing import National, Base

# %%
nr = National()

# %% [markdown]
# ## 2002

# %%
df_02 = pd.read_excel('data/nrsr/nrsr2002.xls')

# %%
df_02.head()
# Out:
#      Unnamed: 0                Unnamed: 1                   Unnamed: 2  \
# 0           NaN                     Počet  Platné hlasy (počet/podiel)
# 1       \nOkres  platných\nhlasov\n spolu                          SZS
# 2                                     NaN                          NaN
# 3  Bratislava I                     30501                          258
# 4           NaN                       NaN                         0.84
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       SDKÚ       SDPO        SDĽ       SMER       HZDS        OKS
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3      12400         23        296       2707       3539        356
# 4      40.65       0.07       0.97       8.87       11.6       1.16
#
#   Unnamed: 9  ... Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        HZD  ...         ANO       B-RRS         ŽAR         SDA         SNJ
# 2        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 3        852  ...        1639          10          71         946          39
# 4       2.79  ...        5.37        0.03        0.23         3.1        0.12
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0         NaN         NaN         NaN         NaN         NaN
# 1        NOSP         SNS        ROSA       ROISR       P SNS
# 2         NaN         NaN         NaN         NaN         NaN
# 3          93         929          19           1         325
# 4         0.3        3.04        0.06           0        1.06
#
# [5 rows x 27 columns]

# %%
df_02 = nr.preprocess_2002(df_02)

# %%
df_02 = Base.set_header_and_clean(df_02)

# %%
df_02 = nr.add_foreign(df_02)

# %%
df_02.head()
# Out:
#             Okres platných hlasov spolu  SZS   SDKÚ SDPO  SDĽ  SMER  HZDS  \
# 0    Bratislava I                 30501  258  12400   23  296  2707  3539
# 1   Bratislava II                 66134  586  22222   82  639  7737  8992
# 2  Bratislava III                 39825  388  13209   42  394  4889  5913
# 3   Bratislava IV                 55082  505  20036   71  522  7196  6278
# 4    Bratislava V                 72225  808  25795   84  746  9921  7467
#
#    OKS   HZD  ...   ANO B-RRS  ŽAR   SDA SNJ NOSP   SNS ROSA ROISR P SNS
# 0  356   852  ...  1639    10   71   946  39   93   929   19     1   325
# 1  415  1997  ...  4434    29  252  1832  61  207  2404   67    24  1053
# 2  312  1256  ...  2734    12  141  1092  64  153  1569   60     5   800
# 3  446  1611  ...  4383    18  270  1739  74  208  1775   75    11   872
# 4  554  1972  ...  5816    29  396  2378  79  220  2413   80    21  1541
#
# [5 rows x 27 columns]

# %%
df_02.shape
# Out:
# (81, 27)

# %%
nr.process_a(df_02, 2002)

# %%
df_test = nr.df

# %%
df_test.head()
# Out:
#    election_year election_type district_id   district_name  \
# 0           2002         NR SR        <NA>    Bratislava I
# 1           2002         NR SR        <NA>   Bratislava II
# 2           2002         NR SR        <NA>  Bratislava III
# 3           2002         NR SR        <NA>   Bratislava IV
# 4           2002         NR SR        <NA>    Bratislava V
#
#    total_district_votes original_party_name party_name  votes
# 0                 30501                 SZS        SZS    258
# 1                 66134                 SZS        SZS    586
# 2                 39825                 SZS        SZS    388
# 3                 55082                 SZS        SZS    505
# 4                 72225                 SZS        SZS    808

# %% [markdown]
# ## 2006

# %%
df_06 = pd.read_excel('data/nrsr/nrsr2006.xls')

# %%
df_06.head()
# Out:
#                                          Počet a podiel platných hlasov odovzdaných pre  politické strany podľa okresov, krajov a SR  \
# 0                                                NaN
# 1                           \nOkres, kraj,\nSR spolu
# 2                                                NaN
# 3                                       Bratislava I
# 4                                                NaN
#
#                        Unnamed: 1                     Unnamed: 2 Unnamed: 3  \
# 0  Počet\nplatných\nhlasov\nspolu  Platné hlasy (počet / podiel)        NaN
# 1                             NaN                             ĽB     S.O.S.
# 2                             NaN                            NaN        NaN
# 3                          23 927                             20          6
# 4                             NaN                           0,08       0,02
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1   Misia 21        SDĽ        ZRS        KDH      SLNKO        ANO  ...
# 2        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 3         33         28          9      2 621         34        224  ...
# 4       0,13       0,11       0,03      10,95       0,14       0,93  ...
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         OKS          PS   ĽS - HZDS         ASV         KSS         SĽS
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         295          52       1 511          13         545          48
# 4        1,23        0,21        6,31        0,05        2,27        0,20
#
#   Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22
# 0         NaN         NaN         NaN         NaN
# 1   SDKÚ - DS        SMER         SNS       NÁDEJ
# 2         NaN         NaN         NaN         NaN
# 3      10 676       3 522       1 417          71
# 4       44,61       14,71        5,92        0,29
#
# [5 rows x 23 columns]

# %%
df_06 = National.preprocess_2006(df_06)

# %%
df_06.head()
# Out:
# 1            Okres platných hlasov spolu  ĽB S.O.S. Misia 21  SDĽ ZRS    KDH  \
# 3     Bratislava I                23 927  20      6       33   28   9  2 621
# 5    Bratislava II                53 581  62     27       50   92  55  3 945
# 7   Bratislava III                32 060  37     14       39   49  23  2 565
# 9    Bratislava IV                45 821  73     15       70   52  48  3 826
# 11    Bratislava V                58 211  75     17       42  100  63  4 138
#
# 1  SLNKO  ANO  ...  OKS   PS ĽS - HZDS ASV    KSS  SĽS SDKÚ - DS    SMER  \
# 3     34  224  ...  295   52     1 511  13    545   48    10 676   3 522
# 5    109  659  ...  289  123     3 784  60  1 540   99    19 958  10 860
# 7     48  408  ...  170   61     2 474  24  1 094   63    11 900   6 785
# 9     82  812  ...  294  116     2 705  55  1 259  110    18 218   9 397
# 11   108  932  ...  403  208     3 006  52  1 586  153    22 012  12 925
#
# 1     SNS NÁDEJ
# 3   1 417    71
# 5   4 168   228
# 7   2 817   162
# 9   3 583   225
# 11  4 907   253
#
# [5 rows x 23 columns]

# %%
df_06.shape
# Out:
# (80, 23)

# %%
df_06 = nr.add_foreign(df_06)

# %%
df_06.shape
# Out:
# (81, 23)

# %%
nr.process_a(df_06, 2006)

# %%
nr.df.shape
# Out:
# (1701, 8)

# %% [markdown]
# ## 2010

# %%
df_10 = pd.read_excel('data/nrsr/nrsr2010.xls')

# %%
df_10.head()
# Out:
#    Kód\nokresu   Názov\nokresu  Počet\nvoleb.\nokrskov  \
# 0          101    Bratislava I                      34
# 1          102   Bratislava II                     107
# 2          103  Bratislava III                      64
# 3          104   Bratislava IV                      82
# 4          105    Bratislava V                     107
#
#    Počet\nvoličov\nzapísaných\nv zoznamoch\nvoličov  \
# 0                                             38113
# 1                                             97490
# 2                                             54886
# 3                                             84085
# 4                                            105818
#
#    Počet\nvoličov,\nktorí sa\nzúčastnili\nna hlasovaní  \
# 0                                              25372
# 1                                              62356
# 2                                              36477
# 3                                              54136
# 4                                              64554
#
#    Počet\nvoličov,\nktorí\nzaslali\nnávratnú\nobálku\nz cudziny  \
# 0                                                168
# 1                                                213
# 2                                                137
# 3                                                270
# 4                                                287
#
#    Počet\nvoličov,\nktorí\nhlasovali\nosobne  Počet\nplatných\nhlasov\nspolu  \
# 0                                      25188                           25045
# 1                                      62094                           61750
# 2                                      36323                           36097
# 3                                      53806                           53615
# 4                                      64229                           64110
#
#    EDS  Únia  ...  KSS   SNS   ND  ZRS   KDH  ĽSNS  SDKÚ - DS  AZEN   SMER  \
# 0   42   173  ...   80   700   65    9  2739    95       8161    24   4738
# 1  104   682  ...  237  2208  163   24  4666   345      17742    54  15136
# 2   61   303  ...  173  1454  109   29  3090   209      10349    45   9310
# 3   92   617  ...  185  1765  144   41  4699   313      15738    79  12888
# 4  111   700  ...  262  2325  186   43  4530   474      18882    82  15232
#
#    MOST - HÍD
# 0        2772
# 1        5954
# 2        2508
# 3        3924
# 4        5133
#
# [5 rows x 26 columns]
