# %%
import pandas as pd

# %% [markdown]
# # nr

# %%
from processing import National

# %%
nr = National()

# %% [markdown]
# ## 2002

# %%
df_02 = pd.read_excel('data/nrsr/nrsr2002.xls')

# %%
df_02.head()
# Out:
#      Unnamed: 0                Unnamed: 1                   Unnamed: 2  \
# 0           NaN                     Počet  Platné hlasy (počet/podiel)
# 1       \nOkres  platných\nhlasov\n spolu                          SZS
# 2                                     NaN                          NaN
# 3  Bratislava I                     30501                          258
# 4           NaN                       NaN                         0.84
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       SDKÚ       SDPO        SDĽ       SMER       HZDS        OKS
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3      12400         23        296       2707       3539        356
# 4      40.65       0.07       0.97       8.87       11.6       1.16
#
#   Unnamed: 9  ... Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        HZD  ...         ANO       B-RRS         ŽAR         SDA         SNJ
# 2        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 3        852  ...        1639          10          71         946          39
# 4       2.79  ...        5.37        0.03        0.23         3.1        0.12
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0         NaN         NaN         NaN         NaN         NaN
# 1        NOSP         SNS        ROSA       ROISR       P SNS
# 2         NaN         NaN         NaN         NaN         NaN
# 3          93         929          19           1         325
# 4         0.3        3.04        0.06           0        1.06
#
# [5 rows x 27 columns]

# %%
df_02 = nr.preprocess_2002(df_02)

# %%
df_02 = nr.set_header_and_clean(df_02)

# %%
df_02 = nr.add_foreign(df_02)

# %%
df_02.head()
# Out:
#             Okres platných hlasov spolu  SZS   SDKÚ SDPO  SDĽ  SMER  HZDS  \
# 0    Bratislava I                 30501  258  12400   23  296  2707  3539
# 1   Bratislava II                 66134  586  22222   82  639  7737  8992
# 2  Bratislava III                 39825  388  13209   42  394  4889  5913
# 3   Bratislava IV                 55082  505  20036   71  522  7196  6278
# 4    Bratislava V                 72225  808  25795   84  746  9921  7467
#
#    OKS   HZD  ...   ANO B-RRS  ŽAR   SDA SNJ NOSP   SNS ROSA ROISR P SNS
# 0  356   852  ...  1639    10   71   946  39   93   929   19     1   325
# 1  415  1997  ...  4434    29  252  1832  61  207  2404   67    24  1053
# 2  312  1256  ...  2734    12  141  1092  64  153  1569   60     5   800
# 3  446  1611  ...  4383    18  270  1739  74  208  1775   75    11   872
# 4  554  1972  ...  5816    29  396  2378  79  220  2413   80    21  1541
#
# [5 rows x 27 columns]

# %%
df_02.shape
# Out:
# (81, 27)

# %%
nr.process_2002(df_02)

# %%
df_test = nr.df

# %%
df_test.head()
# Out:
#    election_year election_type district_id   district_name  \
# 0           2002         NR SR        <NA>    Bratislava I
# 1           2002         NR SR        <NA>   Bratislava II
# 2           2002         NR SR        <NA>  Bratislava III
# 3           2002         NR SR        <NA>   Bratislava IV
# 4           2002         NR SR        <NA>    Bratislava V
#
#    total_district_votes original_party_name party_name  votes
# 0                 30501                 SZS        SZS    258
# 1                 66134                 SZS        SZS    586
# 2                 39825                 SZS        SZS    388
# 3                 55082                 SZS        SZS    505
# 4                 72225                 SZS        SZS    808

# %% [markdown]
# ## 2006

# %%
df_06 = pd.read_excel('data/nrsr/nrsr2006.xls')
