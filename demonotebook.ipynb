# %%
import pandas as pd

# %%
from processing import Demo

# %%
df = pd.read_csv('data/demo/2021/2021_agegroups.csv')

# %%
df = Demo.preprocess_2021(df)

# %%
df.head()
# Out:
#       Kód              Territory unit  pre-productive age (aged 0-14) (%)  \
# 0  SK0101    District of Bratislava I                               15.19
# 1  SK0102   District of Bratislava II                               15.35
# 2  SK0103  District of Bratislava III                               16.47
# 3  SK0104   District of Bratislava IV                               15.64
# 4  SK0105    District of Bratislava V                               15.11
#
#    productive age (aged 15-64) (%)  post-productive age (aged 65+) (%)
# 0                            63.31                               21.51
# 1                            65.38                               19.28
# 2                            65.36                               18.17
# 3                            66.28                               18.08
# 4                            65.83                               19.06
