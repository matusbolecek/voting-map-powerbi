# %%
import pandas as pd

# %% [markdown]
# # ep

# %%
from processing import Euro, Base

# %%
ep = Euro()

# %% [markdown]
# ## 2004

# %%
df_04 = pd.read_excel('data/ep/ep2004.xlsx')

# %%
df_04 = Euro.preprocess_2004(df_04)

# %%
df_04.head()
# Out:
#              Okres SMK-MKP    ANO   SDKÚ MFS ŽS SR  DÚ  KSS     SF SNS, P SNS  \
# 3     Bratislava I     866    586  2 949  20    46  91  356    852        202
# 5    Bratislava II   1 963    979  4 751  26    95  55  679  1 152        373
# 7   Bratislava III     668    628  3 095  10    41  64  513    788        218
# 9    Bratislava IV     865    939  4 397  24    84  86  576  1 160        305
# 11    Bratislava V   1 279  1 203  4 610  19   106  92  645  1 262        360
#
#    SĽS AŽ-OS SMER (tretia cesta) ĽS-HZDS    KDH HZD, ĽÚ  OKS RKDH  Kód Okresu
# 3   18    85               1 359   1 573  2 012     128  466   13       101.0
# 5   13   149               3 005   3 225  2 807     192  398   11       102.0
# 7   17    75               1 897   2 313  1 853     131  312   12       103.0
# 9   27   111               2 759   2 270  2 544     164  464   14       104.0
# 11  29   173               3 604   2 054  2 696     211  501   28       105.0

# %%
ep.process_wide(df_04, 2004)

# %%
ep.df.head()
# Out:
#    election_year election_type district_id   district_name  \
# 0           2004            EP         101    Bratislava I
# 1           2004            EP         102   Bratislava II
# 2           2004            EP         103  Bratislava III
# 3           2004            EP         104   Bratislava IV
# 4           2004            EP         105    Bratislava V
#
#   original_party_name party_name  votes
# 0             SMK-MKP    SMK-MKP    866
# 1             SMK-MKP    SMK-MKP   1963
# 2             SMK-MKP    SMK-MKP    668
# 3             SMK-MKP    SMK-MKP    865
# 4             SMK-MKP    SMK-MKP   1279

# %% [markdown]
# ## 2009

# %%
df_09 = pd.read_excel('data/ep/ep2009.xls')

# %%
df_09.head()
# Out:
#   Počet a podiel platných hlasov odovzdaných pre politické strany podľa okresov  \
# 0                                              Okres
# 1                                                NaN
# 2                                                NaN
# 3                                       Bratislava I
# 4                                                NaN
#
#                      Unnamed: 1 Unnamed: 2                     Unnamed: 3  \
# 0  Počet platných\nhlasov spolu        NaN  Platné hlasy (počet / podiel)
# 1                           NaN        NaN                        ĽS-HZDS
# 2                           NaN        NaN                            NaN
# 3                        11 266                                       592
# 4                           NaN                                      5,25
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1        NaN        SaS        NaN       SMER        NaN         SZ  ...
# 2        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 3                 1 388                 2 211                   527  ...
# 4                 12,32                 19,62                  4,67  ...
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         SNS         NaN        LIGA         NaN         SDĽ         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         393                      40                      48
# 4        3,48                    0,35                    0,42
#
#   Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34
# 0         NaN         NaN         NaN         NaN
# 1          SF         NaN         KDH         NaN
# 2         NaN         NaN         NaN         NaN
# 3         173                   1 156
# 4        1,53                   10,26
#
# [5 rows x 35 columns]

# %%
df_09 = Euro.preprocess_2009(df_09)

# %%
df_09.head()
# Out:
#              Okres ĽS-HZDS    SaS   SMER     SZ SDKÚ- DS  DS Misia 21 ASV  \
# 3     Bratislava I     592  1 388  2 211    527    3 614  37       12  31
# 5    Bratislava II   1 418  2 252  6 401    947    6 743  71       18  59
# 7   Bratislava III     976  1 521  3 903    607    4 193  50       15  51
# 9    Bratislava IV   1 058  2 324  5 541    990    6 335  68       15  75
# 11    Bratislava V   1 043  2 430  5 690  1 048    6 458  74       17  89
#
#    KDS, OKS SMK-MKP  KSS  SNS LIGA  SDĽ   SF    KDH  Kód Okresu
# 3       587     355  102  393   40   48  173  1 156       101.0
# 5       794   1 380  192  963   64  115  377  1 803       102.0
# 7       492     312  175  667   55   54  184  1 243       103.0
# 9       850     385  167  787   71   75  372  1 924       104.0
# 11      887     626  161  961   57  144  480  1 708       105.0

# %%
ep.process_wide(df_09, 2009)

# %% [markdown]
# ## 2014

# %%
df_14 = pd.read_excel('data/ep/ep2014.xlsx')

# %%
df_14.head()
# Out:
#   Počet a podiel platných hlasov odovzdaných pre politické subjekty podľa okresov a za Slovenskú republiku  \
# 0                                                NaN
# 1                                                NaN
# 2                                              Okres
# 3                                                NaN
# 4                                       Bratislava I
#
#                      Unnamed: 1  \
# 0                           NaN
# 1                           NaN
# 2  Počet platných\nhlasov spolu
# 3                           NaN
# 4                          8910
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1  NOVA, Konzervatívni demokrati Slovenska, Občia...
# 2                              Počet platných hlasov
# 3                                                NaN
# 4                                               1662
#
#                    Unnamed: 3                     Unnamed: 4  \
# 0                         NaN                            NaN
# 1                         NaN  Kresťanskodemokratické hnutie
# 2  Podiel platných hlasov v %          Počet platných hlasov
# 3                         NaN                            NaN
# 4                       18.65                            933
#
#                    Unnamed: 5                  Unnamed: 6  \
# 0                         NaN                         NaN
# 1                         NaN  SMER - sociálna demokracia
# 2  Podiel platných hlasov v %       Počet platných hlasov
# 3                         NaN                         NaN
# 4                       10.47                        1349
#
#                    Unnamed: 7               Unnamed: 8  \
# 0                         NaN                      NaN
# 1                         NaN  Slovenská ľudová strana
# 2  Podiel platných hlasov v %    Počet platných hlasov
# 3                         NaN                      NaN
# 4                       15.14                       19
#
#                    Unnamed: 9  ...               Unnamed: 50  \
# 0                         NaN  ...                       NaN
# 1                         NaN  ...  Strana občianskej ľavice
# 2  Podiel platných hlasov v %  ...     Počet platných hlasov
# 3                         NaN  ...                       NaN
# 4                        0.21  ...                         9
#
#                   Unnamed: 51               Unnamed: 52  \
# 0                         NaN                       NaN
# 1                         NaN  Slovenská národná strana
# 2  Podiel platných hlasov v %     Počet platných hlasov
# 3                         NaN                       NaN
# 4                         0.1                       182
#
#                   Unnamed: 53  \
# 0                         NaN
# 1                         NaN
# 2  Podiel platných hlasov v %
# 3                         NaN
# 4                        2.04
#
#                                          Unnamed: 54  \
# 0                                                NaN
# 1  Slovenská demokratická a kresťanská únia - Dem...
# 2                              Počet platných hlasov
# 3                                                NaN
# 4                                               1546
#
#                   Unnamed: 55                                  Unnamed: 56  \
# 0                         NaN                                          NaN
# 1                         NaN  PRIAMA DEMOKRACIA, Kresťanská ľudová strana
# 2  Podiel platných hlasov v %                        Počet platných hlasov
# 3                         NaN                                          NaN
# 4                       17.35                                           45
#
#                   Unnamed: 57  \
# 0                         NaN
# 1                         NaN
# 2  Podiel platných hlasov v %
# 3                         NaN
# 4                         0.5
#
#                                          Unnamed: 58  \
# 0                                                NaN
# 1  Strana maďarskej komunity - Magyar Közösség Pá...
# 2                              Počet platných hlasov
# 3                                                NaN
# 4                                                 84
#
#                   Unnamed: 59
# 0                         NaN
# 1                         NaN
# 2  Podiel platných hlasov v %
# 3                         NaN
# 4                        0.94
#
# [5 rows x 60 columns]

# %%
df_14 = Euro.preprocess_2014(df_14)

# %%
df_14.head()
# Out:
#             Okres  \
# 4    Bratislava I
# 5   Bratislava II
# 6  Bratislava III
# 7   Bratislava IV
# 8    Bratislava V
#
#   NOVA, Konzervatívni demokrati Slovenska, Občianska konzervatívna strana  \
# 4                                               1662
# 5                                               2363
# 6                                               1610
# 7                                               2338
# 8                                               2086
#
#   Kresťanskodemokratické hnutie SMER - sociálna demokracia  \
# 4                           933                       1349
# 5                          1729                       3741
# 6                          1090                       2313
# 7                          1601                       3188
# 8                          1569                       2963
#
#   Slovenská ľudová strana Národ a Spravodlivosť - naša strana  \
# 4                      19                                  84
# 5                      31                                 244
# 6                      27                                 134
# 7                      32                                 248
# 8                      42                                 241
#
#   Magnificat Slovakia DEMOKRATICKÁ OBČIANSKA STRANA  \
# 4                  45                             4
# 5                 111                            13
# 6                  65                             6
# 7                  79                            11
# 8                 125                            13
#
#   7 STATOČNÝCH REGIONÁLNA STRANA SLOVENSKA  \
# 4                                       13
# 5                                       31
# 6                                       14
# 7                                       29
# 8                                       33
#
#   Maďarská kresťanskodemokratická aliancia - Magyar Kereszténydemokrata Szövetség  \
# 4                                                  3
# 5                                                  6
# 6                                                  3
# 7                                                  5
# 8                                                  7
#
#    ... Sloboda a Solidarita Strana moderného Slovenska  \
# 4  ...                 1149                         39
# 5  ...                 2155                         48
# 6  ...                 1379                         20
# 7  ...                 2109                         54
# 8  ...                 2084                         45
#
#   Komunistická strana Slovenska ÚSVIT Strana občianskej ľavice  \
# 4                            86    17                        9
# 5                           170    39                       14
# 6                           105    19                        4
# 7                           182    39                        3
# 8                           165    47                       14
#
#   Slovenská národná strana  \
# 4                      182
# 5                      548
# 6                      404
# 7                      520
# 8                      504
#
#   Slovenská demokratická a kresťanská únia - Demokratická strana  \
# 4                                               1546
# 5                                               2639
# 6                                               1775
# 7                                               2570
# 8                                               2360
#
#   PRIAMA DEMOKRACIA, Kresťanská ľudová strana  \
# 4                                          45
# 5                                          59
# 6                                          58
# 7                                          62
# 8                                          95
#
#   Strana maďarskej komunity - Magyar Közösség Pártja Kód Okresu
# 4                                                 84      101.0
# 5                                                305      102.0
# 6                                                 88      103.0
# 7                                                 87      104.0
# 8                                                187      105.0
#
# [5 rows x 31 columns]

# %%
ep.process_wide(df_14, 2014)

# %% [markdown]
# ## 2019

# %%
df_19 = pd.read_excel('data/ep/ep2019.xlsx')

# %%
df_19.head()
# Out:
#   Počet a podiel platných hlasov odovzdaných pre politické subjekty za okresy  \
# 0                                                NaN
# 1                                          Kód kraja
# 2                                                NaN
# 3                                                  1
# 4                                                  1
#
#           Unnamed: 1           Unnamed: 2             Unnamed: 3  Unnamed: 4  \
# 0                NaN                  NaN                    NaN         NaN
# 1        Názov kraja  Kód územného obvodu  Názov územného obvodu  Kód okresu
# 2                NaN                  NaN                    NaN         NaN
# 3  Bratislavský kraj                  101             Bratislava         101
# 4  Bratislavský kraj                  101             Bratislava         101
#
#      Unnamed: 5                  Unnamed: 6  \
# 0           NaN                         NaN
# 1  Názov okresu  Číslo politického subjektu
# 2           NaN                         NaN
# 3  Bratislava I                           1
# 4  Bratislava I                           2
#
#                                    Unnamed: 7             Unnamed: 8  \
# 0                                         NaN                    NaN
# 1                  Názov politického subjektu  Počet platných hlasov
# 2                                         NaN                    NaN
# 3                  SMER - sociálna demokracia                   1004
# 4  Kresťanská demokracia - Život a prosperita                    127
#
#                    Unnamed: 9  \
# 0                         NaN
# 1  Podiel platných hlasov v %
# 2                         NaN
# 3                        6.45
# 4                        0.81
#
#                                          Unnamed: 10  \
# 0                                                NaN
# 1  Počet voličov, ktorí využili právo prednostnéh...
# 2                                                NaN
# 3                                                807
# 4                                                113
#
#                                          Unnamed: 11
# 0                                                NaN
# 1  Podiel voličov, ktorí využili právo prednostné...
# 2                                                NaN
# 3                                              80.37
# 4                                              88.97

# %%
df_19 = Euro.preprocess_2020(df_19)

# %%
df_19.head()
# Out:
# 1 Kód Okresu         Okres                                  party_name votes
# 3        101  Bratislava I                  SMER - sociálna demokracia  1004
# 4        101  Bratislava I  Kresťanská demokracia - Život a prosperita   127
# 5        101  Bratislava I      Kotleba - Ľudová strana Naše Slovensko   969
# 6        101  Bratislava I                     KOREKTÚRA - Andrej Hryc   145
# 7        101  Bratislava I                    Slovenská národná strana   411

# %%
ep.process_long(df_19, 2019)

# %% [markdown]
# ## 2024

# %%
df_24 = pd.read_excel('data/ep/ep2024.xlsx')

# %%
df_24.head()
# Out:
#   Počet a podiel platných hlasov odovzdaných pre politické subjekty za okresy  \
# 0                                                NaN
# 1                                          Kód kraja
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#           Unnamed: 1           Unnamed: 2             Unnamed: 3  Unnamed: 4  \
# 0                NaN                  NaN                    NaN         NaN
# 1        Názov kraja  Kód územného obvodu  Názov územného obvodu  Kód okresu
# 2  Bratislavský kraj                  101             Bratislava         101
# 3  Bratislavský kraj                  101             Bratislava         101
# 4  Bratislavský kraj                  101             Bratislava         101
#
#      Unnamed: 5                  Unnamed: 6                  Unnamed: 7  \
# 0           NaN                         NaN                         NaN
# 1  Názov okresu  Číslo politického subjektu  Názov politického subjektu
# 2  Bratislava I                           1           Slovenský PATRIOT
# 3  Bratislava I                           2                 MySlovensko
# 4  Bratislava I                           3                   Demokrati
#
#               Unnamed: 8                  Unnamed: 9  \
# 0                    NaN                         NaN
# 1  Počet platných hlasov  Podiel platných hlasov v %
# 2                     20                         0.1
# 3                      1                           0
# 4                   1060                        5.36
#
#                                          Unnamed: 10  \
# 0                                                NaN
# 1  Počet voličov, ktorí využili právo prednostnéh...
# 2                                                 17
# 3                                                  0
# 4                                                975
#
#                                          Unnamed: 11
# 0                                                NaN
# 1  Podiel voličov, ktorí využili právo prednostné...
# 2                                                 85
# 3                                                  0
# 4                                              91.98

# %%
df_24 = Euro.preprocess_2020(df_24)

# %%
df_24.head()
# Out:
# 1 Kód Okresu         Okres                            party_name votes
# 2        101  Bratislava I                     Slovenský PATRIOT    20
# 3        101  Bratislava I                           MySlovensko     1
# 4        101  Bratislava I                             Demokrati  1060
# 5        101  Bratislava I  Magyar Szövetség - Maďarská aliancia    74
# 6        101  Bratislava I      Spájame Občanov Slovenska - SOSK    15

# %%
ep.process_long(df_24, 2024)

# %%
ep.df.shape
# Out:
# (9295, 7)
